# %%
from pathlib import Path

shapefile_path = Path('/home/joyvan/shared-public/QGreenland-Researcher-Workshop/group-six/HydroLakes_polys_v10_Greenland_clp');

# %%
from osgeo import ogr, osr, gdal
import gdaltools
from ogr import ogrinfo
ogrinfo -al -shapefile_path

info = gdaltools.ogrinfo("thelayer.shp", "thelayer", geom=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [9], line 2
#       1 from osgeo import ogr, osr, gdal
# ----> 2 from ogr import ogrinfo
#       3 ogrinfo -al -shapefile_path
#
# ModuleNotFoundError: No module named 'ogr'
