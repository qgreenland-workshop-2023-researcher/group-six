# %%
import xarray as xra
import geopandas as gpd

# %%
shapefile_path = ('/home/joyvan/shared-public/QGreenland-Researcher-Workshop/group-six/HydroLakes_polys_v10_Greenland_clp.shp')

# %%
gdf = gpd.read_file(shapefile_path)
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona/ogrext.pyx:136, in fiona.ogrext.gdal_open_vector()
#
# File fiona/_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: /home/joyvan/shared-public/QGreenland-Researcher-Workshop/group-six/HydroLakes_polys_v10_Greenland_clp.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 gdf = gpd.read_file(shapefile_path)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/geopandas/io/file.py:259, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     256     path_or_bytes = filename
#     258 if engine == "fiona":
# --> 259     return _read_file_fiona(
# ...

# %%
ds = xra.open_dataset(shapefile_path)
ds
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 ds = xra.open_dataset(shapefile_path)
#       2 ds
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/xarray/backends/api.py:510, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, backend_kwargs, **kwargs)
#     507     kwargs.update(backend_kwargs)
#     509 if engine is None:
# --> 510     engine = plugins.guess_engine(filename_or_obj)
#     512 backend = plugins.get_backend(engine)
#     514 decoders = _resolve_decoders_kwargs(
#     515     decode_cf,
#     516     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     522     decode_coords=decode_coords,
#     523 )
#
# ...

# %%
ogrinfo -al -so shapefile_path
# Out:
#   Cell In [4], line 1
#     ogrinfo -al -so shapefile_path
#                     ^
# SyntaxError: invalid syntax
