# %%
from pathlib import Path
import xarray as xra
from osgeo import gdal

# %%
datafile_path = Path('/home/jovyan/shared-public/QGreenland-Researcher-Workshop/group-six/HydroLakes_polys_v10_Greenland_clp.shp')
print(datafile_path)
# Out:
# /home/jovyan/shared-public/QGreenland-Researcher-Workshop/group-six/HydroLakes_polys_v10_Greenland_clp.shp

# %%
import fiona
with fiona.open('/home/jovyan/shared-public/QGreenland-Researcher-Workshop/group-six/HydroLakes_polys_v10_Greenland_clp.shp') as hydrolakes:
    print(hydrolakes.crs)
    print(hydrolakes.schema)
    print(hydrolakes[0].geometry.coordinates)
    for feature in hydrolakes:
        print(feature.geometry.type)
# Out:
# EPSG:4326
# {'properties': {'Hylak_id': 'int:9', 'Lake_name': 'str:40', 'Country': 'str:35', 'Continent': 'str:15', 'Poly_src': 'str:10', 'Lake_type': 'int:4', 'Grand_id': 'int:4', 'Lake_area': 'float:13.2', 'Shore_len': 'float:13.2', 'Shore_dev': 'float:7.2', 'Vol_total': 'float:13.2', 'Vol_res': 'float:13.2', 'Vol_src': 'int:4', 'Depth_avg': 'float:7.1', 'Dis_avg': 'float:13.3', 'Res_time': 'float:13.1', 'Elevation': 'int:4', 'Slope_100': 'float:7.2', 'Wshd_area': 'float:13.1', 'Pour_long': 'float:13.6', 'Pour_lat': 'float:13.6'}, 'geometry': 'Polygon'}
# ...

# %%
# %%bash
# ogrinfo -al -so '/home/jovyan/shared-public/QGreenland-Researcher-Workshop/group-six/HydroLakes_polys_v10_Greenland_clp.shp'
# Out:
# INFO: Open of `/home/jovyan/shared-public/QGreenland-Researcher-Workshop/group-six/HydroLakes_polys_v10_Greenland_clp.shp'
#       using driver `ESRI Shapefile' successful.
#
# Layer name: HydroLakes_polys_v10_Greenland_clp
# Metadata:
#   DBF_DATE_LAST_UPDATE=2023-05-23
# Geometry: Polygon
# Feature Count: 3028
# Extent: (-72.662231, 59.852529) - (-14.766404, 83.575951)
# Layer SRS WKT:
# GEOGCRS["WGS 84",
#     DATUM["World Geodetic System 1984",
#         ELLIPSOID["WGS 84",6378137,298.257223563,
#             LENGTHUNIT["metre",1]]],
#     PRIMEM["Greenwich",0,
#         ANGLEUNIT["degree",0.0174532925199433]],
#     CS[ellipsoidal,2],
#         AXIS["latitude",north,
#             ORDER[1],
#             ANGLEUNIT["degree",0.0174532925199433]],
#         AXIS["longitude",east,
#             ORDER[2],
#             ANGLEUNIT["degree",0.0174532925199433]],
#     ID["EPSG",4326]]
# Data axis to CRS axis mapping: 2,1
# Hylak_id: Integer (9.0)
# Lake_name: String (40.0)
# ...
